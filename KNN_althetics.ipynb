# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy.stats import norm
from scipy import linalg
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from src import utils_knn, utils_knn_2, utils_ald

# %%
data = pd.read_csv('data/athlete_cleaned.csv')
data_short = pd.read_csv('data/athlete_cleaned_short.csv')

# %%
data
# Out:
#       gender                                 event   medal        type  year  \
# 0        Men             Double FITA Round Amputee    Gold     Archery  1980
# 1        Men          Double FITA Round Paraplegic    Gold     Archery  1980
# 2        Men         Double FITA Round Tetraplegic    Gold     Archery  1980
# 3        Men   Double FITA Round Novice Paraplegic    Gold     Archery  1980
# 4        Men  Double FITA Round Novice Tetraplegic    Gold     Archery  1980
# ...      ...                                   ...     ...         ...   ...
# 19542  Women                    Sitting Volleyball  Bronze  Volleyball  2016
# 19543  Women                    Sitting Volleyball  Bronze  Volleyball  2016
# 19544  Women                    Sitting Volleyball  Bronze  Volleyball  2016
# 19545  Women                    Sitting Volleyball  Bronze  Volleyball  2016
# 19546  Women                    Sitting Volleyball  Bronze  Volleyball  2016
#
#           country  abb                        athlete
# 0         Denmark  DEN                    LARSEN Finn
# 1      FR Germany  FRG                       GEISS H.
# 2          Canada  CAN                      PARKER T.
# 3          Mexico  MEX                 CHAVEZ Alfredo
# 4         Finland  FIN                   KARKAINEN K.
# ...           ...  ...                            ...
# 19542      Brazil  BRA         DE ALMEIDA SILVA Nurya
# 19543      Brazil  BRA       DE OLIVEIRA DIAS Edwarda
# 19544      Brazil  BRA  MARIA LEIRIA DE CASTRO Camila
# 19545      Brazil  BRA                 PEREIRA Pamela
# 19546      Brazil  BRA       RODRIGUES BATISTA Laiana
#
# [19547 rows x 8 columns]

# %%
data_coor = pd.read_csv('data/country_coordinates.csv')

# %%
data_coor
# Out:
#            country   longitude   latitude
# 0       FR Germany   10.451526  51.165691
# 1           Sweden   18.643501  60.128161
# 2          Belgium    4.469936  50.503887
# 3    Great Britain   -3.435973  55.378051
# 4      Netherlands    5.291266  52.132633
# ..             ...         ...        ...
# 111          Syria   38.996815  34.802075
# 112     Kazakhstan   66.923684  48.019573
# 113  Faroe Islands   -6.911806  61.892635
# 114           Peru  -75.015152  -9.189967
# 115      Singapore  103.819836   1.352083
#
# [116 rows x 3 columns]

# %%
data_full = pd.read_csv('data/data_full.csv')

# %%
data_full
# Out:
#       gender   medal        type  year     country  abb   longitude   latitude
# 0        Men    Gold     Archery  1980     Denmark  DEN    9.501785  56.263920
# 1        Men  Silver     Archery  1980  FR Germany  FRG   10.451526  51.165691
# 2        Men  Bronze     Archery  1980       Japan  JPN  138.252924  36.204824
# 3        Men    Gold     Archery  1980  FR Germany  FRG   10.451526  51.165691
# 4        Men  Silver     Archery  1980     Belgium  BEL    4.469936  50.503887
# ...      ...     ...         ...   ...         ...  ...         ...        ...
# 19440  Women  Bronze  Volleyball  2016      Brazil  BRA  -51.925280 -14.235004
# 19441  Women  Bronze  Volleyball  2016      Brazil  BRA  -51.925280 -14.235004
# 19442  Women  Bronze  Volleyball  2016      Brazil  BRA  -51.925280 -14.235004
# 19443  Women  Bronze  Volleyball  2016      Brazil  BRA  -51.925280 -14.235004
# 19444  Women  Bronze  Volleyball  2016      Brazil  BRA  -51.925280 -14.235004
#
# [19445 rows x 8 columns]

# %%
def select_sport(data, sport_name):
    return data[data['type'] == sport_name]


data_by_sport = []
data_full['type'].unique()
# Out:
# array(['Archery', 'Athletics', 'Basketball', 'Fencing', 'Powerlifting',
#        'Rugby', 'Swimming', 'Table Tennis', 'Wheelchair Tennis',
#        'Triathlon', 'Volleyball'], dtype=object)

# %%
data_by_sport.append(select_sport(data_full, "Archery"))
len(data_by_sport[-1])
# Out:
# 401

# %%
data_by_sport.append(select_sport(data_full, "Athletics"))
data_by_sport[-1]['year'].unique()
# Out:
# array([1980, 1984, 1988, 1992, 1996, 2000, 2004, 2008, 2012, 2016],
#       dtype=int64)

# %%
data_by_sport.append(select_sport(data_full, "Basketball"))
len(data_by_sport[-1])
# Out:
# 594

# %%
data_by_sport.append(select_sport(data_full, "Fencing"))
len(data_by_sport[-1])
# Out:
# 665

# %%
data_by_sport.append(select_sport(data_full, "Powerlifting"))
len(data_by_sport[-1])
# Out:
# 403

# %%
data_by_sport.append(select_sport(data_full, "Rugby"))
len(data_by_sport[-1])
# Out:
# 173

# %%
data_by_sport.append(select_sport(data_full, "Table Tennis"))
len(data_by_sport[-1]), data_by_sport[-1]["year"].unique()
# Out:
# (1383,
#  array([1980, 1984, 1988, 1992, 1996, 2000, 2004, 2008, 2012, 2016],
#        dtype=int64))

# %%
data_by_sport.append(select_sport(data_full, "Wheelchair Tennis"))
len(data_by_sport[-1]), data_by_sport[-1]["year"].unique()
# Out:
# (1360,
#  array([1980, 1984, 1988, 1992, 1996, 2000, 2004, 2008, 2012, 2016],
#        dtype=int64))

# %%
data_by_sport.append(select_sport(data_full, "Swimming"))
len(data_by_sport[-1])
# Out:
# 6188

# %%
data_by_sport.append(select_sport(data_full, "Triathlon"))
len(data_by_sport[-1])
# Out:
# 18

# %%
data_by_sport.append(select_sport(data_full, "Volleyball"))
len(data_by_sport[-1])
# Out:
# 575

# %%
data_by_sport
# Out:
# [    gender   medal     type  year     country  abb   longitude   latitude
#  0      Men    Gold  Archery  1980     Denmark  DEN    9.501785  56.263920
#  1      Men  Silver  Archery  1980  FR Germany  FRG   10.451526  51.165691
#  2      Men  Bronze  Archery  1980       Japan  JPN  138.252924  36.204824
#  3      Men    Gold  Archery  1980  FR Germany  FRG   10.451526  51.165691
#  4      Men  Silver  Archery  1980     Belgium  BEL    4.469936  50.503887
#  ..     ...     ...      ...   ...         ...  ...         ...        ...
#  396  Mixed    Gold  Archery  2016       China  CHN  104.195397  35.861660
#  397  Mixed  Silver  Archery  2016        Iran  IRI   53.688046  32.427908
#  398  Mixed  Silver  Archery  2016        Iran  IRI   53.688046  32.427908
#  399  Mixed  Bronze  Archery  2016       Italy  ITA   12.567380  41.871940
#  400  Mixed  Bronze  Archery  2016       Italy  ITA   12.567380  41.871940
#
#  [401 rows x 8 columns],
#       gender   medal       type  year      country  abb   longitude   latitude
#  401     Men    Gold  Athletics  1980       Mexico  MEX -102.552784  23.634501
#  402     Men  Silver  Athletics  1980       Canada  CAN -106.346771  56.130366
#  403     Men  Bronze  Athletics  1980  Switzerland  SUI    8.227512  46.818188
#  404     Men    Gold  Athletics  1980       Sweden  SWE   18.643501  60.128161
#  405     Men  Silver  Athletics  1980       Mexico  MEX -102.552784  23.634501
#  ...     ...     ...        ...   ...          ...  ...         ...        ...
#  8081  Women    Gold  Athletics  2016        China  CHN  104.195397  35.861660
#  8082  Women  Silver  Athletics  2016    Australia  AUS  133.775136 -25.274398
#  8083  Women  Silver  Athletics  2016    Australia  AUS  133.775136 -25.274398
#  8084  Women  Silver  Athletics  2016    Australia  AUS  133.775136 -25.274398
#  8085  Women  Silver  Athletics  2016    Australia  AUS  133.775136 -25.274398
#
#  [7685 rows x 8 columns],
#         gender   medal        type  year                   country  abb  \
#  8086      Men    Gold  Basketball  1980                    Israel  ISR
#  8087      Men  Silver  Basketball  1980               Netherlands  NED
#  8088      Men  Bronze  Basketball  1980  United States of America  USA
#  8089    Women    Gold  Basketball  1980                FR Germany  FRG
#  8090    Women  Silver  Basketball  1980                    Israel  ISR
#  ...       ...     ...         ...   ...                       ...  ...
#  8675  UNKNOWN  Bronze  Basketball  2016               Netherlands  NED
#  8676  UNKNOWN  Bronze  Basketball  2016               Netherlands  NED
#  8677  UNKNOWN  Bronze  Basketball  2016               Netherlands  NED
#  8678  UNKNOWN  Bronze  Basketball  2016               Netherlands  NED
#  8679  UNKNOWN  Bronze  Basketball  2016               Netherlands  NED
#
#        longitude   latitude
#  8086  34.851612  31.046051
#  8087   5.291266  52.132633
#  8088 -95.712891  37.090240
#  8089  10.451526  51.165691
#  8090  34.851612  31.046051
#  ...         ...        ...
#  8675   5.291266  52.132633
#  8676   5.291266  52.132633
#  8677   5.291266  52.132633
#  8678   5.291266  52.132633
#  8679   5.291266  52.132633
#
#  [594 rows x 8 columns],
#       gender   medal     type  year        country  abb  longitude   latitude
#  8680    Men    Gold  Fencing  1980         France  FRA   2.213749  46.227638
#  8681    Men  Silver  Fencing  1980  Great Britain  GBR  -3.435973  55.378051
#  8682    Men  Bronze  Fencing  1980          Italy  ITA  12.567380  41.871940
#  8683    Men    Gold  Fencing  1980         France  FRA   2.213749  46.227638
#  8684    Men  Silver  Fencing  1980     FR Germany  FRG  10.451526  51.165691
#  ...     ...     ...      ...   ...            ...  ...        ...        ...
#  9340  Women  Silver  Fencing  2016        Hungary  HUN  19.503304  47.162494
#  9341  Women  Silver  Fencing  2016        Hungary  HUN  19.503304  47.162494
#  9342  Women  Bronze  Fencing  2016          Italy  ITA  12.567380  41.871940
#  9343  Women  Bronze  Fencing  2016          Italy  ITA  12.567380  41.871940
#  9344  Women  Bronze  Fencing  2016          Italy  ITA  12.567380  41.871940
#
#  [665 rows x 8 columns],
#       gender   medal          type  year                   country  abb  \
#  9345    Men    Gold  Powerlifting  1984  United States of America  USA
#  9346    Men  Silver  Powerlifting  1984             Great Britain  GBR
#  9347    Men    Gold  Powerlifting  1984  United States of America  USA
#  9348    Men    Gold  Powerlifting  1984                    France  FRA
#  9349    Men    Gold  Powerlifting  1984                    Sweden  SWE
#  ...     ...     ...           ...   ...                       ...  ...
#  9743  Women  Silver  Powerlifting  2016                    Jordan  JOR
#  9744  Women  Bronze  Powerlifting  2016                    Mexico  MEX
#  9745  Women    Gold  Powerlifting  2016                   Nigeria  NGR
#  9746  Women  Silver  Powerlifting  2016                    Poland  POL
#  9747  Women  Bronze  Powerlifting  2016               Netherlands  NED
#
#         longitude   latitude
#  9345  -95.712891  37.090240
#  9346   -3.435973  55.378051
#  9347  -95.712891  37.090240
#  9348    2.213749  46.227638
#  9349   18.643501  60.128161
#  ...          ...        ...
#  9743   36.238414  30.585164
#  9744 -102.552784  23.634501
#  9745    8.675277   9.081999
#  9746   19.145136  51.919438
#  9747    5.291266  52.132633
#
#  [403 rows x 8 columns],
#       gender   medal   type  year                   country  abb   longitude  \
#  9748  Mixed    Gold  Rugby  2000  United States of America  USA  -95.712891
#  9749  Mixed    Gold  Rugby  2000  United States of America  USA  -95.712891
#  9750  Mixed    Gold  Rugby  2000  United States of America  USA  -95.712891
#  9751  Mixed    Gold  Rugby  2000  United States of America  USA  -95.712891
#  9752  Mixed    Gold  Rugby  2000  United States of America  USA  -95.712891
#  ...     ...     ...    ...   ...                       ...  ...         ...
#  9916  Mixed  Bronze  Rugby  2016                     Japan  JPN  138.252924
#  9917  Mixed  Bronze  Rugby  2016                     Japan  JPN  138.252924
#  9918  Mixed  Bronze  Rugby  2016                     Japan  JPN  138.252924
#  9919  Mixed  Bronze  Rugby  2016                     Japan  JPN  138.252924
#  9920  Mixed  Bronze  Rugby  2016                     Japan  JPN  138.252924
#
#         latitude
#  9748  37.090240
#  9749  37.090240
#  9750  37.090240
#  9751  37.090240
#  9752  37.090240
#  ...         ...
#  9916  36.204824
#  9917  36.204824
#  9918  36.204824
#  9919  36.204824
#  9920  36.204824
#
#  [173 rows x 8 columns],
#        gender   medal          type  year                   country  abb  \
#  16109    Men    Gold  Table Tennis  1980                   Austria  AUT
#  16110    Men  Silver  Table Tennis  1980                     Korea  KOR
#  16111    Men  Bronze  Table Tennis  1980  United States of America  USA
#  16112    Men    Gold  Table Tennis  1980                     Korea  KOR
#  16113    Men  Silver  Table Tennis  1980                   Austria  AUT
#  ...      ...     ...           ...   ...                       ...  ...
#  17487  Women  Silver  Table Tennis  2016                     China  CHN
#  17488  Women  Silver  Table Tennis  2016                     China  CHN
#  17489  Women  Bronze  Table Tennis  2016                    Brazil  BRA
#  17490  Women  Bronze  Table Tennis  2016                    Brazil  BRA
#  17491  Women  Bronze  Table Tennis  2016                    Brazil  BRA
#
#          longitude   latitude
#  16109   14.550072  47.516231
#  16110  127.766922  35.907757
#  16111  -95.712891  37.090240
#  16112  127.766922  35.907757
#  16113   14.550072  47.516231
#  ...           ...        ...
#  17487  104.195397  35.861660
#  17488  104.195397  35.861660
#  17489  -51.925280 -14.235004
#  17490  -51.925280 -14.235004
#  17491  -51.925280 -14.235004
#
#  [1383 rows x 8 columns],
#        gender   medal               type  year                   country  abb  \
#  17492    Men    Gold  Wheelchair Tennis  1980                   Austria  AUT
#  17493    Men  Silver  Wheelchair Tennis  1980                     Korea  KOR
#  17494    Men  Bronze  Wheelchair Tennis  1980  United States of America  USA
#  17495    Men    Gold  Wheelchair Tennis  1980                     Korea  KOR
#  17496    Men  Silver  Wheelchair Tennis  1980                   Austria  AUT
#  ...      ...     ...                ...   ...                       ...  ...
#  18847  Women  Silver  Wheelchair Tennis  2016                     China  CHN
#  18848  Women  Silver  Wheelchair Tennis  2016                     China  CHN
#  18849  Women  Bronze  Wheelchair Tennis  2016                    Brazil  BRA
#  18850  Women  Bronze  Wheelchair Tennis  2016                    Brazil  BRA
#  18851  Women  Bronze  Wheelchair Tennis  2016                    Brazil  BRA
#
#          longitude   latitude
#  17492   14.550072  47.516231
#  17493  127.766922  35.907757
#  17494  -95.712891  37.090240
#  17495  127.766922  35.907757
#  17496   14.550072  47.516231
#  ...           ...        ...
#  18847  104.195397  35.861660
#  18848  104.195397  35.861660
#  18849  -51.925280 -14.235004
#  18850  -51.925280 -14.235004
#  18851  -51.925280 -14.235004
#
#  [1360 rows x 8 columns],
#        gender   medal      type  year                   country  abb  \
#  9921     Men    Gold  Swimming  1980             Great Britain  GBR
#  9922     Men  Silver  Swimming  1980                   Finland  FIN
#  9923     Men  Bronze  Swimming  1980                FR Germany  FRG
#  9924     Men    Gold  Swimming  1980                    Canada  CAN
#  9925     Men  Silver  Swimming  1980  United States of America  USA
#  ...      ...     ...       ...   ...                       ...  ...
#  16104  Mixed  Bronze  Swimming  2016                   Ukraine  UKR
#  16105  Mixed  Bronze  Swimming  2016                   Ukraine  UKR
#  16106  Mixed  Bronze  Swimming  2016                   Ukraine  UKR
#  16107  Mixed  Bronze  Swimming  2016                   Ukraine  UKR
#  16108  Mixed  Bronze  Swimming  2016                   Ukraine  UKR
#
#          longitude   latitude
#  9921    -3.435973  55.378051
#  9922    25.748151  61.924110
#  9923    10.451526  51.165691
#  9924  -106.346771  56.130366
#  9925   -95.712891  37.090240
#  ...           ...        ...
#  16104   31.165580  48.379433
#  16105   31.165580  48.379433
#  16106   31.165580  48.379433
#  16107   31.165580  48.379433
#  16108   31.165580  48.379433
#
#  [6188 rows x 8 columns],
#        gender   medal       type  year                   country  abb  \
#  18852    Men    Gold  Triathlon  2016               Netherlands  NED
#  18853    Men  Silver  Triathlon  2016               Netherlands  NED
#  18854    Men  Bronze  Triathlon  2016                     Italy  ITA
#  18855    Men    Gold  Triathlon  2016             Great Britain  GBR
#  18856    Men  Silver  Triathlon  2016                     Italy  ITA
#  18857    Men  Bronze  Triathlon  2016                   Morocco  MAR
#  18858    Men    Gold  Triathlon  2016                   Germany  GER
#  18859    Men  Silver  Triathlon  2016                    Canada  CAN
#  18860    Men  Bronze  Triathlon  2016                     Spain  ESP
#  18861  Women    Gold  Triathlon  2016  United States of America  USA
#  18862  Women  Silver  Triathlon  2016  United States of America  USA
#  18863  Women  Bronze  Triathlon  2016  United States of America  USA
#  18864  Women    Gold  Triathlon  2016  United States of America  USA
#  18865  Women  Silver  Triathlon  2016             Great Britain  GBR
#  18866  Women  Bronze  Triathlon  2016                    France  FRA
#  18867  Women    Gold  Triathlon  2016                 Australia  AUS
#  18868  Women  Silver  Triathlon  2016             Great Britain  GBR
#  18869  Women  Bronze  Triathlon  2016             Great Britain  GBR
#
#          longitude   latitude
#  18852    5.291266  52.132633
#  18853    5.291266  52.132633
#  18854   12.567380  41.871940
#  18855   -3.435973  55.378051
#  18856   12.567380  41.871940
#  18857   -7.092620  31.791702
#  18858   10.451526  51.165691
#  18859 -106.346771  56.130366
#  18860   -3.749220  40.463667
#  18861  -95.712891  37.090240
#  18862  -95.712891  37.090240
#  18863  -95.712891  37.090240
#  18864  -95.712891  37.090240
#  18865   -3.435973  55.378051
#  18866    2.213749  46.227638
#  18867  133.775136 -25.274398
#  18868   -3.435973  55.378051
#  18869   -3.435973  55.378051  ,
#        gender   medal        type  year      country  abb  longitude   latitude
#  18870    Men    Gold  Volleyball  1980  Netherlands  NED   5.291266  52.132633
#  18871    Men  Silver  Volleyball  1980       Sweden  SWE  18.643501  60.128161
#  18872    Men  Bronze  Volleyball  1980   Yugoslavia  YUG  21.005859  44.016521
#  18873    Men    Gold  Volleyball  1980       Israel  ISR  34.851612  31.046051
#  18874    Men    Gold  Volleyball  1980       Israel  ISR  34.851612  31.046051
#  ...      ...     ...         ...   ...          ...  ...        ...        ...
#  19440  Women  Bronze  Volleyball  2016       Brazil  BRA -51.925280 -14.235004
#  19441  Women  Bronze  Volleyball  2016       Brazil  BRA -51.925280 -14.235004
#  19442  Women  Bronze  Volleyball  2016       Brazil  BRA -51.925280 -14.235004
#  19443  Women  Bronze  Volleyball  2016       Brazil  BRA -51.925280 -14.235004
#  19444  Women  Bronze  Volleyball  2016       Brazil  BRA -51.925280 -14.235004
#
#  [575 rows x 8 columns]]

# %%
data_archery = data_by_sport[0]
data_archery
# Out:
#     gender   medal     type  year     country  abb   longitude   latitude
# 0      Men    Gold  Archery  1980     Denmark  DEN    9.501785  56.263920
# 1      Men  Silver  Archery  1980  FR Germany  FRG   10.451526  51.165691
# 2      Men  Bronze  Archery  1980       Japan  JPN  138.252924  36.204824
# 3      Men    Gold  Archery  1980  FR Germany  FRG   10.451526  51.165691
# 4      Men  Silver  Archery  1980     Belgium  BEL    4.469936  50.503887
# ..     ...     ...      ...   ...         ...  ...         ...        ...
# 396  Mixed    Gold  Archery  2016       China  CHN  104.195397  35.861660
# 397  Mixed  Silver  Archery  2016        Iran  IRI   53.688046  32.427908
# 398  Mixed  Silver  Archery  2016        Iran  IRI   53.688046  32.427908
# 399  Mixed  Bronze  Archery  2016       Italy  ITA   12.567380  41.871940
# 400  Mixed  Bronze  Archery  2016       Italy  ITA   12.567380  41.871940
#
# [401 rows x 8 columns]

# %%
cls_archery = KNeighborsClassifier(n_neighbors=10)
X_archery = pd.DataFrame()
X_archery['longitude'] = data_archery['longitude']
X_archery['latitude'] = data_archery['latitude']
y_archery = data_archery['medal']
utils_knn.plot_clustering(X_archery, y_archery)
plt.show()

# %%
X_archery_train, X_archery_val, y_archery_train, y_archery_val = train_test_split(X_archery, y_archery, train_size=0.66)
cls_archery.fit(X_archery_train, y_archery_train) # len(X_archery_train ) = 0.8 * len(X_archery)
labels = cls_archery.predict(X_archery_val)
right = 0
false = 0
print(y_archery_val)
a = y_archery_val.tolist()
y_archery_val_cpy = []
for i in range(len(labels)):
    if labels[i] ==  a[i]:
        right += 1
    else:
        false += 1
print('eff = ', right , false)
# Out:
# 48       Gold
# 246      Gold
# 319      Gold
# 232    Bronze
# 139      Gold
#         ...
# 254      Gold
# 303    Silver
# 138      Gold
# 295    Bronze
# 294    Silver
# Name: medal, Length: 137, dtype: object
# eff =  40 97

# %%
data_athletics = data_by_sport[1]
data_athletics
# Out:
#      gender   medal       type  year      country  abb   longitude   latitude
# 401     Men    Gold  Athletics  1980       Mexico  MEX -102.552784  23.634501
# 402     Men  Silver  Athletics  1980       Canada  CAN -106.346771  56.130366
# 403     Men  Bronze  Athletics  1980  Switzerland  SUI    8.227512  46.818188
# 404     Men    Gold  Athletics  1980       Sweden  SWE   18.643501  60.128161
# 405     Men  Silver  Athletics  1980       Mexico  MEX -102.552784  23.634501
# ...     ...     ...        ...   ...          ...  ...         ...        ...
# 8081  Women    Gold  Athletics  2016        China  CHN  104.195397  35.861660
# 8082  Women  Silver  Athletics  2016    Australia  AUS  133.775136 -25.274398
# 8083  Women  Silver  Athletics  2016    Australia  AUS  133.775136 -25.274398
# 8084  Women  Silver  Athletics  2016    Australia  AUS  133.775136 -25.274398
# 8085  Women  Silver  Athletics  2016    Australia  AUS  133.775136 -25.274398
#
# [7685 rows x 8 columns]

# %%
cls_athletics = KNeighborsClassifier(n_neighbors=3)
X_athletics = pd.DataFrame()
X_athletics['longitude'] = data_athletics['longitude']
X_athletics['latitude'] = data_athletics['latitude']
y_athletics = data_athletics['medal']
utils_knn.plot_clustering(X_athletics, y_athletics)
plt.show()

# %%
X_athletics_train, X_athletics_val, y_athletics_train, y_athletics_val = train_test_split(X_athletics, y_athletics, train_size=0.66)
cls_athletics.fit(X_athletics_train, y_athletics_train) 
labels_athletics = cls_athletics.predict(X_athletics_val)
right = 0
false = 0
print(y_athletics_val)
a = y_athletics_val.tolist()
y_athletics_val_cpy = []
for i in range(len(labels_athletics)):
    if labels_athletics[i] ==  a[i]:
        right += 1
    else:
        false += 1
print('eff = ', right , false)
# Out:
# 1706    Bronze
# 2910    Bronze
# 5893    Silver
# 3164    Silver
# 6244    Silver
#          ...
# 631     Bronze
# 6948      Gold
# 7148    Silver
# 3233    Bronze
# 5641    Bronze
# Name: medal, Length: 2613, dtype: object
# eff =  893 1720

# %%
n_neighbors_list = np.unique(np.round(np.geomspace(1, 500, 100)).astype(int))
gen = utils_knn_2.knn_simple_validation(X_athletics_train, y_athletics_train, X_athletics_val, y_athletics_val, n_neighbors_list)
df = pd.DataFrame(gen, columns=["# neighbors", "accuracy", "degrés de liberté"])
sp = sns.lineplot(x="degrés de liberté", y="accuracy", data=df)
sp.set(xscale="log")
# Out:
# [None]

# %%
Kopt = df.groupby("# neighbors").mean().accuracy.idxmax()
Kopt
# Out:
# 126

# %%
data_athletics = pd.read_csv('data/medal_country_year_athletics.csv')
data_athletics
# Out:
#       year      country   longitude   latitude value
# 0      0.0      Denmark    9.501785  56.263920     S
# 1      0.0   FR Germany   10.451526  51.165691     G
# 2      0.0       Canada -106.346771  56.130366     G
# 3      0.0       Mexico -102.552784  23.634501     G
# 4      0.0      Finland   25.748151  61.924110     S
# ...    ...          ...         ...        ...   ...
# 1135   9.0   Mozambique   35.529562 -18.665695     B
# 1136   9.0        Libya   17.228331  26.335100     0
# 1137   9.0  Philippines  121.774017  12.879721     0
# 1138   9.0         Laos  102.495496  19.856270     0
# 1139   9.0        Syria   38.996815  34.802075     0
#
# [1140 rows x 5 columns]

# %%
def calculer_distance(longitudeA,latitudeA,yearA,longitudeB,latitudeB,yearB):
    K = 1
    result = sqrt((longitudeA-longitudeB)^2 + (latitudeA-latitudeB)^2) + K * abs(yearA-yearB)
    return result

# %%
cls_atlhetics = KNeighborsClassifier(n_neighbors=5)
X_athletics = pd.DataFrame()
X_athletics['longitude'] = data_athletics['longitude']
X_athletics['latitude'] = data_athletics['latitude']
X_athletics['year'] = data_athletics['year']
y_athletics = data_athletics['value']

# %%
X_athletics_train, X_athletics_val, y_athletics_train, y_athletics_val = train_test_split(X_athletics, y_athletics, train_size=0.66)
cls_athletics.fit(X_athletics_train, y_athletics_train) 
labels_athletics = cls_athletics.predict(X_athletics_val)
right = 0
false = 0
a = y_athletics_val.tolist()
y_athletics_val_cpy = []
for i in range(len(labels_athletics)):
    if labels_athletics[i] ==  a[i]:
        right += 1
    else:
        false += 1
print('eff = ', right , false)
# Out:
# eff =  217 171

# %%
n_neighbors_list = np.unique(np.round(np.geomspace(1, 500, 100)).astype(int))
gen = utils_knn_2.knn_simple_validation(X_athletics_train, y_athletics_train, X_athletics_val, y_athletics_val, n_neighbors_list)
df = pd.DataFrame(gen, columns=["# neighbors", "accuracy", "degrés de liberté"])

# %%
sp1 = sns.lineplot(x="degrés de liberté", y="accuracy", data=df)
sp1.set(xscale="log")
# Out:
# [None]

# %%
sp2 = sns.lineplot(x="# neighbors", y="accuracy", data=df)
sp2.set(xscale="log")
# Out:
# [None]

# %%
Kopt = df.groupby("# neighbors").mean().accuracy.idxmax()
Kopt
# Out:
# 2

# %%
cls = KNeighborsClassifier(n_neighbors=Kopt)
c=1
for year in data_athletics["year"].unique():
    plt.figure(c)
    plt.subplot().set_title(year*4 + 1980)
    x_visual = pd.DataFrame()
    data_year = data_athletics[data_athletics["year"] == year]
    
    x_visual['longitude'] = data_year['longitude']
    x_visual['latitude'] = data_year['latitude']
    y_visual = data_year['value']
    cls.fit(x_visual, y_visual)
    utils_knn.plot_clustering(x_visual, y_visual)
    utils_ald.add_decision_boundary(cls)
    c += 1
# Out:
# C:\Users\Ho Xuan Vinh\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Ho Xuan Vinh\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Ho Xuan Vinh\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Ho Xuan Vinh\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Ho Xuan Vinh\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Ho Xuan Vinh\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Ho Xuan Vinh\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Ho Xuan Vinh\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Ho Xuan Vinh\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\Ho Xuan Vinh\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
train_size = 0.90
n_splits = 10
gen = utils_knn_2.knn_multiple_validation(X_athletics, y_athletics, n_splits, train_size, n_neighbors_list)
df = pd.DataFrame(gen, columns=["# neighbors", "accuracy", "degrés de liberté"])
Kopt = df.groupby("# neighbors").mean().accuracy.idxmax()
Kopt
# Out:
# 2

# %%
sp = sns.lineplot(x="degrés de liberté", y="accuracy", err_style="bars", ci="sd", data=df)
sp.set(xscale="log")
plt.show()

# %%
n_folds = 10
gen = utils_knn_2.knn_cross_validation(X_athletics, y_athletics, n_folds, n_neighbors_list)
df = pd.DataFrame(gen, columns=["# neighbors", "accuracy", "degrés de liberté"])
Kopt = df.groupby("# neighbors").mean().accuracy.idxmax()
Kopt
# Out:
# 2

# %%
sp = sns.lineplot(x="degrés de liberté", y="accuracy", err_style="bars", ci="sd", data=df)
sp.set(xscale="log")
plt.show()

# %%
from sklearn.model_selection import cross_val_score
n_folds = 10
gen = utils_knn_2.knn_cross_validation2(X_athletics, y_athletics, n_folds, n_neighbors_list)
df = pd.DataFrame(gen, columns=["# neighbors", "accuracy", "degrés de liberté"])
Kopt = df.groupby("# neighbors").mean().accuracy.idxmax()
Kopt
# Out:
# 2

# %%
sp = sns.lineplot(x="degrés de liberté", y="accuracy", err_style="bars", ci="sd", data=df)
sp.set(xscale="log")
plt.show()
