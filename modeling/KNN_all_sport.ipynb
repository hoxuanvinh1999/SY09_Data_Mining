# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy.stats import norm
from scipy import linalg
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from src import utils_knn, utils_knn_2, utils_ald

# %%
data_full = pd.read_csv('data/data_full.csv')

# %%
data_full
# Out:
#       gender   medal        type  year     country  abb   longitude   latitude
# 0        Men    Gold     Archery  1980     Denmark  DEN    9.501785  56.263920
# 1        Men  Silver     Archery  1980  FR Germany  FRG   10.451526  51.165691
# 2        Men  Bronze     Archery  1980       Japan  JPN  138.252924  36.204824
# 3        Men    Gold     Archery  1980  FR Germany  FRG   10.451526  51.165691
# 4        Men  Silver     Archery  1980     Belgium  BEL    4.469936  50.503887
# ...      ...     ...         ...   ...         ...  ...         ...        ...
# 19440  Women  Bronze  Volleyball  2016      Brazil  BRA  -51.925280 -14.235004
# 19441  Women  Bronze  Volleyball  2016      Brazil  BRA  -51.925280 -14.235004
# 19442  Women  Bronze  Volleyball  2016      Brazil  BRA  -51.925280 -14.235004
# 19443  Women  Bronze  Volleyball  2016      Brazil  BRA  -51.925280 -14.235004
# 19444  Women  Bronze  Volleyball  2016      Brazil  BRA  -51.925280 -14.235004
#
# ...

# %%
data_all_sport = pd.read_csv('data/medal_country_year_all_sport.csv')
data_all_sport
# Out:
#       year      country   longitude   latitude value
# 0      0.0      Denmark    9.501785  56.263920     B
# 1      0.0   FR Germany   10.451526  51.165691     G
# 2      0.0       Canada -106.346771  56.130366     G
# 3      0.0       Mexico -102.552784  23.634501     G
# 4      0.0      Finland   25.748151  61.924110     S
# ...    ...          ...         ...        ...   ...
# 1135   9.0   Mozambique   35.529562 -18.665695     B
# 1136   9.0        Libya   17.228331  26.335100     0
# 1137   9.0  Philippines  121.774017  12.879721     B
# 1138   9.0         Laos  102.495496  19.856270     0
# 1139   9.0        Syria   38.996815  34.802075     0
#
# [1140 rows x 5 columns]

# %%
def calculer_distance(longitudeA,latitudeA,yearA,longitudeB,latitudeB,yearB):
    K = 1
    result = sqrt((longitudeA-longitudeB)^2 + (latitudeA-latitudeB)^2) + K * abs(yearA-yearB)
    return result

# %%
cls_all_sport = KNeighborsClassifier(n_neighbors=5)
X_all_sport = pd.DataFrame()
X_all_sport['longitude'] = data_all_sport['longitude']
X_all_sport['latitude'] = data_all_sport['latitude']
X_all_sport['year'] = data_all_sport['year']
y_all_sport = data_all_sport['value']

# %%
X_all_sport_train, X_all_sport_val, y_all_sport_train, y_all_sport_val = train_test_split(X_all_sport, y_all_sport, train_size=0.66)
cls_all_sport.fit(X_all_sport_train, y_all_sport_train) 
labels_all_sport = cls_all_sport.predict(X_all_sport_val)
right = 0
false = 0
a = y_all_sport_val.tolist()
y_all_sport_val_cpy = []
for i in range(len(labels_all_sport)):
    if labels_all_sport[i] ==  a[i]:
        right += 1
    else:
        false += 1
print('eff = ', right , false)
# Out:
# eff =  219 169

# %%
n_neighbors_list = np.unique(np.round(np.geomspace(1, 500, 100)).astype(int))
gen = utils_knn_2.knn_simple_validation(X_all_sport_train, y_all_sport_train, X_all_sport_val, y_all_sport_val, n_neighbors_list)
df = pd.DataFrame(gen, columns=["# neighbors", "accuracy", "degrés de liberté"])

# %%
sp1 = sns.lineplot(x="degrés de liberté", y="accuracy", data=df)
sp1.set(xscale="log")
plt.savefig("new images/all_sport_knn_simple_validation_medal_by_longlat_accuracy_1")

# %%
sp2 = sns.lineplot(x="# neighbors", y="accuracy", data=df)
sp2.set(xscale="log")
plt.savefig("new images/all_sport_knn_simple_validation_medal_by_longlat_accuracy_2")

# %%
Kopt = df.groupby("# neighbors").mean().accuracy.idxmax()
Kopt
# Out:
# 2

# %%
cls = KNeighborsClassifier(n_neighbors=Kopt)
c=1
for year in data_all_sport["year"].unique():
    plt.figure(c)
    plt.subplot().set_title(year*4 + 1980)
    x_visual = pd.DataFrame()
    data_year = data_all_sport[data_all_sport["year"] == year]
    
    x_visual['longitude'] = data_year['longitude']
    x_visual['latitude'] = data_year['latitude']
    y_visual = data_year['value']
    cls.fit(x_visual, y_visual)
    utils_knn.plot_clustering(x_visual, y_visual)
    utils_ald.add_decision_boundary(cls)
    c += 1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# ...

# %%
train_size = 0.90
n_splits = 10
gen = utils_knn_2.knn_multiple_validation(X_all_sport, y_all_sport, n_splits, train_size, n_neighbors_list)
df = pd.DataFrame(gen, columns=["# neighbors", "accuracy", "degrés de liberté"])
Kopt = df.groupby("# neighbors").mean().accuracy.idxmax()
Kopt
# Out:
# 2

# %%
sp = sns.lineplot(x="degrés de liberté", y="accuracy", err_style="bars", ci="sd", data=df)
sp.set(xscale="log")
plt.savefig("new images/all_sport_knn_multiple_validation_medal_by_longlat_accuracy")

# %%
n_folds = 10
gen = utils_knn_2.knn_cross_validation(X_all_sport, y_all_sport, n_folds, n_neighbors_list)
df = pd.DataFrame(gen, columns=["# neighbors", "accuracy", "degrés de liberté"])
Kopt = df.groupby("# neighbors").mean().accuracy.idxmax()
Kopt
# Out:
# 2

# %%
sp = sns.lineplot(x="degrés de liberté", y="accuracy", err_style="bars", ci="sd", data=df)
sp.set(xscale="log")
plt.savefig("new images/all_sport_knn_cross_validation_medal_by_longlat_accuracy")

# %%
from sklearn.model_selection import cross_val_score
n_folds = 10
gen = utils_knn_2.knn_cross_validation2(X_all_sport, y_all_sport, n_folds, n_neighbors_list)
df = pd.DataFrame(gen, columns=["# neighbors", "accuracy", "degrés de liberté"])
Kopt = df.groupby("# neighbors").mean().accuracy.idxmax()
Kopt
# Out:
# 2

# %%
sp = sns.lineplot(x="degrés de liberté", y="accuracy", err_style="bars", ci="sd", data=df)
sp.set(xscale="log")
plt.savefig("new images/all_sport_knn_cross_validation2_medal_by_longlat_accuracy")
