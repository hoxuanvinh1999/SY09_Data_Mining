# %%
import pandas as pd
import numpy as np

# %%
athletes = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2021/2021-08-03/athletes.csv')

# %%
athletes.to_csv("data/athletes.csv",index=False)

# %%
athletes_raw = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2021/2021-08-03/athletes.csv')
athletes_raw.to_csv("data/athletes_raw.csv",index=False)

# %%
athletes.head()
# Out:
#   gender                         event   medal         athlete  abb country  \
# 0    Men     Double FITA Round Amputee    Gold     LARSEN Finn  DEN     NaN
# 1    Men     Double FITA Round Amputee  Silver  BRENNE Manfred  FRG     NaN
# 2    Men     Double FITA Round Amputee  Bronze      SATO Masao  JPN     NaN
# 3    Men  Double FITA Round Paraplegic    Gold        GEISS H.  FRG     NaN
# 4    Men  Double FITA Round Paraplegic  Silver        GRUN Guy  BEL     NaN
#
#    grp_id     type  year guide
# 0     NaN  Archery  1980   NaN
# 1     NaN  Archery  1980   NaN
# 2     NaN  Archery  1980   NaN
# 3     NaN  Archery  1980   NaN
# 4     NaN  Archery  1980   NaN

# %%
pd.read_csv("data/athletes.csv").head()
# Out:
#   gender                         event   medal         athlete  abb country  \
# 0    Men     Double FITA Round Amputee    Gold     LARSEN Finn  DEN     NaN
# 1    Men     Double FITA Round Amputee  Silver  BRENNE Manfred  FRG     NaN
# 2    Men     Double FITA Round Amputee  Bronze      SATO Masao  JPN     NaN
# 3    Men  Double FITA Round Paraplegic    Gold        GEISS H.  FRG     NaN
# 4    Men  Double FITA Round Paraplegic  Silver        GRUN Guy  BEL     NaN
#
#    grp_id     type  year guide
# 0     NaN  Archery  1980   NaN
# 1     NaN  Archery  1980   NaN
# 2     NaN  Archery  1980   NaN
# 3     NaN  Archery  1980   NaN
# 4     NaN  Archery  1980   NaN
